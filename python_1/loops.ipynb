# %%
'tis but a flesh wound'
# Out:
# 'tis but a flesh wound'

# %%
# for THING in CONTAINDER_OF_THINGS:
   # do somethign with that THING
for letter in 'tis but a flesh wound':
    print(letter)
# Out:
# t
# i
# s
#
# b
# u
# t
#
# a
#
# f
# l
# e
# s
# h
#
# w
# o
# u
# n
# d

# %%
s = 'tis but a flesh wound'

# %%
s
# Out:
# 'tis but a flesh wound'

# %%
s[0]
# Out:
# 't'

# %%
s[:5]
# Out:
# 'tis b'

# %%
s[-1]
# Out:
# 'd'

# %%
s[-5:]
# Out:
# 'wound'

# %%
elements = [0, 'letters', True, 3.14]

# %%
elements
# Out:
# [0, 'letters', True, 3.14]

# %%
elements = ['oxygen', 'nitrogen', 'argon']

# %%
for element in elements:
    print(element)
# Out:
# oxygen
# nitrogen
# argon

# %%
for element in elements:
    for letter in element:
        print(letter)
# Out:
# o
# x
# y
# g
# e
# n
# n
# i
# t
# r
# o
# g
# e
# n
# a
# r
# g
# o
# n

# %%
for elem in elements:
    print(elem)
# Out:
# oxygen
# nitrogen
# argon

# %%
import glob

# %%
glob.glob('data/i*.csv')
# Out:
# ['data/inflammation-09.csv',
#  'data/inflammation-06.csv',
#  'data/inflammation-02.csv',
#  'data/inflammation-03.csv',
#  'data/inflammation-08.csv',
#  'data/inflammation-10.csv',
#  'data/inflammation-11.csv',
#  'data/inflammation-04.csv',
#  'data/inflammation-07.csv',
#  'data/inflammation-05.csv',
#  'data/inflammation-12.csv',
#  'data/inflammation-01.csv']

# %%
inflammation_files = glob.glob('data/i*.csv')

# %%
inflammation_files
# Out:
# ['data/inflammation-09.csv',
#  'data/inflammation-06.csv',
#  'data/inflammation-02.csv',
#  'data/inflammation-03.csv',
#  'data/inflammation-08.csv',
#  'data/inflammation-10.csv',
#  'data/inflammation-11.csv',
#  'data/inflammation-04.csv',
#  'data/inflammation-07.csv',
#  'data/inflammation-05.csv',
#  'data/inflammation-12.csv',
#  'data/inflammation-01.csv']

# %%
type(inflammation_files)
# Out:
# list

# %%
import numpy as np
import matplotlib.pyplot as plt

# write a function that takes a filename and prints out that figure
# the funciton should take 1 paramter, a filename
# 'data/inflmamtion-02.csv'
# 'inflammation-02.csv'

def analyze(filepath):
    """Takes a inflammation file and plots the mean, max, and min
    """
    data = np.loadtxt(filepath, delimiter=',')

    # calculate the avg, max, min across each column of data
    avg_inflammation = np.mean(data, axis=0)
    max_inflammation = np.max(data, axis=0)
    min_inflammation = np.min(data, axis=0)

    # plot the results in a single figure
    fig = plt.figure(figsize=(10, 3))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)

    axes1.set_ylabel('average')
    axes1.plot(avg_inflammation)

    axes2.set_ylabel('max')
    axes2.plot(max_inflammation)

    axes3.set_ylabel('min')
    axes3.plot(min_inflammation)

    fig.tight_layout()

    plt.show()

# sort my output!
for inflammation_f in inflammation_files:
    print(inflammation_f)
    analyze(inflammation_f)
# Out:
# data/inflammation-09.csv
# data/inflammation-06.csv
# data/inflammation-02.csv
# data/inflammation-03.csv
# data/inflammation-08.csv
# data/inflammation-10.csv
# data/inflammation-11.csv
# data/inflammation-04.csv
# data/inflammation-07.csv
# data/inflammation-05.csv
# data/inflammation-12.csv
# data/inflammation-01.csv

# %%
elements = ['oxygen', 'hydrogen', 'nitrogen']

# %%
elements
# Out:
# ['oxygen', 'hydrogen', 'nitrogen']

# %%
elements.sort()

# %%
elements
# Out:
# ['hydrogen', 'nitrogen', 'oxygen']

# %%
elements = ['oxygen', 'hydrogen', 'nitrogen']

# %%
sort = elements.sort()

# %%
print(sort)
# Out:
# None

# %%
inflammation_files.sort()
for inflammation_f in inflammation_files:
    print(inflammation_f)
    analyze(inflammation_f)
# Out:
# data/inflammation-01.csv
# data/inflammation-02.csv
# data/inflammation-03.csv
# data/inflammation-04.csv
# data/inflammation-05.csv
# data/inflammation-06.csv
# data/inflammation-07.csv
# data/inflammation-08.csv
# data/inflammation-09.csv
# data/inflammation-10.csv
# data/inflammation-11.csv
# data/inflammation-12.csv
