# %%
# write a function that takes in a filename
# and prints out the plots for
# mean, max, min of the inflammation data

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
# use the glob module/library to find all the inflammation files
# and write a `for` loop to plot all the files

# %%
def analyze(filename):
    data = np.loadtxt(filename, delimiter=',')

    inflam_mean = np.mean(data, axis=0)
    inflam_min = np.min(data, axis=0)
    inflam_max = np.max(data, axis=0)

    fig = plt.figure(figsize=(10, 3))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)

    axes1.set_ylabel('average')
    axes1.plot(inflam_mean)

    axes2.set_ylabel('minimum')
    axes2.plot(inflam_min)

    axes3.set_ylabel('maximum')
    axes3.plot(inflam_max)

    fig.tight_layout()

    plt.show()

# %%
inflammation_files = glob.glob('data/inflammation-*')

# %%
for i_file in inflammation_files:
    print(i_file)
    analyze(i_file)
# Out:
# data/inflammation-09.csv
# data/inflammation-06.csv
# data/inflammation-02.csv
# data/inflammation-03.csv
# data/inflammation-08.csv
# data/inflammation-10.csv
# data/inflammation-11.csv
# data/inflammation-04.csv
# data/inflammation-07.csv
# data/inflammation-05.csv
# data/inflammation-12.csv
# data/inflammation-01.csv
