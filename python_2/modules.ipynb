# %%
import analyze

# to automatically reload your module without kernel restart
import importlib
importlib.reload(analyze)
# Out:
# <module 'analyze' from '/home/dchen/swc-python-2/analyze.py'>

# %%
analyze.analyze('data/inflammation-01.csv')

# %% [markdown]
# Write your interpretation
